# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

print("Done Import")
# Out:
# Done Import

# %%
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', None)

energy = pd.read_excel("energy-future-prices_src-intercontinental-exchange-ice.xlsx")
energy
# Out:
#        Value        Date  Product Id ProductID_Contract Exchange City  \
# 0      -1.00  2020-08-07        5629         5629_MAR21     SINGAPORE
# 1      -2.05  2020-02-20        5629         5629_MAR21     SINGAPORE
# ...      ...         ...         ...                ...           ...
# 17774  30.35  2020-03-19          95           95_MAY21        LONDON
# 17775  28.16  2020-03-18          95           95_MAY21        LONDON
#
#       Super Region Time Level   Unit                           Source  \
# 0      GLOBAL DATA      DAILY  PRICE  INTERCONTINENTAL EXCHANGE - ICE
# 1      GLOBAL DATA      DAILY  PRICE  INTERCONTINENTAL EXCHANGE - ICE
# ...            ...        ...    ...                              ...
# 17774  GLOBAL DATA      DAILY  PRICE  INTERCONTINENTAL EXCHANGE - ICE
# 17775  GLOBAL DATA      DAILY  PRICE  INTERCONTINENTAL EXCHANGE - ICE
#
#                   Sub-Sector                    Product Type Exchange Country  \
# 0      ENERGY FUTURES PRICES           CRUDE OIL AND REFINED        SINGAPORE
# 1      ENERGY FUTURES PRICES           CRUDE OIL AND REFINED        SINGAPORE
# ...                      ...                             ...              ...
# 17774  ENERGY FUTURES PRICES  CRUDE OIL AND REFINED PRODUCTS   UNITED KINGDOM
# 17775  ENERGY FUTURES PRICES  CRUDE OIL AND REFINED PRODUCTS   UNITED KINGDOM
#
#                   Product Description
# 0      URALS NWE  VS DATED BRENT SWAP
# 1      URALS NWE  VS DATED BRENT SWAP
# ...                               ...
# 17774        SINGAPORE NAPHTHA FUTURE
# 17775        SINGAPORE NAPHTHA FUTURE
#
# [17776 rows x 13 columns]
