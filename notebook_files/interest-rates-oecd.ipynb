# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

print("Done Import")
# Out:
# Done Import

# %%
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', None)

interest_rates = pd.read_excel("interest-rates_src-oecd.xlsx")
interest_rates
# Out:
#       Value        Date      Sub-Sector Super Region            Measure  \
# 0      1.40  2014-12-31  INTEREST RATES  GLOBAL DATA  PERCENT PER ANNUM
# 1      9.19  1995-03-31  INTEREST RATES  GLOBAL DATA  PERCENT PER ANNUM
# ...     ...         ...             ...          ...                ...
# 2378   4.71  2013-06-30  INTEREST RATES  GLOBAL DATA  PERCENT PER ANNUM
# 2379   3.33  2007-09-30  INTEREST RATES  GLOBAL DATA  PERCENT PER ANNUM
#
#      Frequency                   Region Source  \
# 0            Q  EURO AREA(16 COUNTRIES)   OECD
# 1            Q  EURO AREA(16 COUNTRIES)   OECD
# ...        ...                      ...    ...
# 2378         Q                    CHINA   OECD
# 2379         Q                    CHINA   OECD
#
#                               Indicator Subject
# 0     LONG-TERM INTEREST RATES FORECAST   TOTAL
# 1     LONG-TERM INTEREST RATES FORECAST   TOTAL
# ...                                 ...     ...
# 2378          SHORT-TERM INTEREST RATES   TOTAL
# 2379          SHORT-TERM INTEREST RATES   TOTAL
#
# [2380 rows x 10 columns]
